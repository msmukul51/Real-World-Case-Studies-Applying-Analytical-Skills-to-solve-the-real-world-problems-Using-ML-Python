# %% [markdown]
# <a href="https://colab.research.google.com/github/msmukul51/Real-World-Case-Studies-Applying-Analytical-Skills-to-solve-the-real-world-problems-Using-ML-Python/blob/main/SOLAR_POWER_GENERATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #About the data set and its effect on power generation.

# %% [markdown]
# ##1.temperature_2_m_above_gnd-It is the temprature at the height of 2m from the ground.
# Solar panels have a temperature coefficient, which indicates how much the efficiency of the panel decreases with an increase in temperature. Most silicon-based solar panels have a negative temperature coefficient of about -0.3% to -0.5% per degree Celsius. This means that for every degree Celsius increase in temperature above 25°C (77°F), the efficiency of the solar panel decreases by 0.3% to 0.5%.
#
# ##2.relative_humidity_2_m_above_gnd-It is the Relative Humidity at the height of 2m from the ground.
#
# Atmospheric Absorption and Scattering: High relative humidity means more water vapor in the air, which can lead to increased absorption and scattering of sunlight. This reduces the amount of direct solar radiation reaching the solar panels, decreasing their efficiency and power output
#
# ##3.mean_sea_level_pressure_MSL
#
# Air Mass and Solar Irradiance: At higher altitudes (above mean sea level), the atmosphere is thinner. This means there is less air mass for the sunlight to travel through, resulting in reduced scattering and absorption of solar radiation. Consequently, solar panels at higher altitudes receive more intense solar irradiance, potentially increasing their efficiency and energy output.
#
# Absorption and Scattering: Conversely, at lower altitudes (close to or below mean sea level), the atmosphere is denser, leading to increased scattering and absorption of sunlight. This can decrease the amount of direct solar radiation reaching the panels and reduce their performance.
#
# Temperature Variations with Altitude: Higher altitudes typically have cooler temperatures, which can benefit solar panel efficiency. As mentioned earlier, solar panels perform better at lower temperatures, so the cooler climate at higher altitudes can offset some of the efficiency losses caused by other factors.
#
# ##4.total_precipitation_sfc-
#
# The term "total_precipitation_sfc" refers to the total amount of precipitation that reaches the surface of the Earth over a specified period. This precipitation includes all forms of water, such as:
#
# Rain: Liquid water droplets that fall from clouds.
# Snow: Frozen water crystals that fall from clouds.
# Sleet: Small pellets of ice created by the freezing of raindrops or partially melted snowflakes before they reach the ground.
# Hail: Balls or irregular lumps of ice that fall from thunderstorms.
# Freezing Rain: Rain that falls as liquid but freezes upon impact with a surface
#
# ##5.snowfall_amount_sfc-
#
# The term "snowfall_amount_sfc" refers to the total amount of snowfall that reaches the surface of the Earth over a specified period. This metric specifically measures the accumulation of snow, typically expressed in millimeters (mm) or inches.
#
# ##6.total_cloud_cover_sfc-
#
# The term "total_cloud_cover_sfc" refers to the fraction of the sky covered by clouds as observed from the Earth's surface. It is typically expressed as a percentage or in oktas (eighths), where 0 represents a completely clear sky and 8 represents a fully overcast sky.
#
# ##7.high_cloud_cover_high_cld_lay-
#
# The term "high_cloud_cover_high_cld_lay" refers to the fraction of the sky covered by high-altitude clouds, typically observed at higher layers of the atmosphere. High clouds are generally found above 6,000 meters (approximately 20,000 feet). These clouds are typically composed of ice crystals and include cloud types such as cirrus, cirrostratus, and cirrocumulus.
#
# ##8.medium_cloud_cover_mid_cld_lay-
#
# The term "medium_cloud_cover_mid_cld_lay" refers to the fraction of the sky covered by clouds located at mid-altitudes in the atmosphere. These mid-level clouds typically form between 2,000 and 6,000 meters (approximately 6,500 to 20,000 feet) above the Earth's surface. Common types of mid-level clouds include altostratus and altocumulus.
#
# ##9.low_cloud_cover_low_cld_lay-
#
# The term "low_cloud_cover_low_cld_lay" refers to the fraction of the sky covered by clouds at low altitudes, typically below 2,000 meters (approximately 6,500 feet). Low clouds include types such as stratus, stratocumulus, and nimbostratus, which are generally closer to the Earth's surface and can have a significant impact on solar energy generation.
#
# ##10.shortwave_radiation_backwards_sfc-
#
# The term "shortwave_radiation_backwards_sfc" typically refers to the measurement or calculation of the shortwave radiation that is directed back towards the Earth's surface from the atmosphere. Shortwave radiation consists of solar radiation, which includes visible light, ultraviolet (UV) radiation, and shorter wavelengths of infrared radiation.
#
# ##11.wind_speed_10_m_above_gnd-
#
# "Wind_speed_10_m_above_gnd" refers to the measurement of wind speed at a standard height of 10 meters above the ground level. This parameter is commonly used in meteorology and environmental science to describe the speed of wind flow near the Earth's surface.
#
# ##12.wind_direction_10_m_above_gnd-
#
# "Wind_direction_10_m_above_gnd" refers to the measurement of wind direction at a standard height of 10 meters above the ground level. This parameter indicates the direction from which the wind is blowing at that specific elevation.
#
# ##13.wind_speed_80_m_above_gnd-
#
# ##14.wind_direction_80_m_above_gnd-
#
# ##15.wind_speed_900_mb-
#
# "Wind_speed_900_mb" refers to the measurement of wind speed at a specific pressure level in the atmosphere, specifically at 900 millibars (mb) above mean sea level. This parameter provides information about wind speed at a certain altitude in the atmosphere, rather than near the Earth's surface.
#
# ##16.wind_direction_900_mb-
#
# ##17.wind_gust_10_m_above_gnd-
#
# "Wind_gust_10_m_above_gnd" refers to the measurement of wind gusts at a standard height of 10 meters above the ground level. A wind gust is a sudden, brief increase in wind speed that typically lasts for a few seconds to a minute, often associated with passing weather phenomena such as thunderstorms, cold fronts, or convective activity.
#
# ##18.angle_of_incidence-
#
# The "angle of incidence" refers to the angle at which a ray of light or other electromagnetic radiation strikes a surface. In various fields, including physics, optics, and engineering, the angle of incidence plays a crucial role in determining how radiation interacts with surfaces, such as reflection, refraction, or absorption.
#
# ##19.zenith-
#
# The zenith is the point directly overhead in the sky relative to an observer's position on the Earth's surface. It serves as a fundamental reference point in astronomy, navigation, and meteorology. Understanding the zenith angle and its variations is essential for celestial navigation, astronomical observations, solar measurements, and meteorological studies.
#
# ##20.azimuth-
#
# The azimuth is like the compass direction of a celestial object or point in the sky, measured clockwise from north in the horizontal plane. Using the analogy of navigating with a compass, observers can understand how azimuth provides a way to describe the direction of objects relative to their position on Earth. In the example of finding the Sun's azimuth, observers use this measurement to track the Sun's position and understand its movement throughout the day.
#
# ##21.generated_power_kw-

# %% [markdown]
# #Importing referances and libraries.

# %%
pip install catboost

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV,KFold,cross_val_score
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,BaggingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.feature_selection import SelectKBest,chi2,f_regression,mutual_info_regression,SelectFromModel,RFE,SequentialFeatureSelector
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA,KernelPCA,FactorAnalysis,FastICA
from scipy.stats import zscore,shapiro,pearsonr,f_oneway,ttest_ind,chi2_contingency,kstest,normaltest,skewtest,kurtosistest
from scipy.special import boxcox1p
from statsmodels.stats.outliers_influence import variance_inflation_factor,OLSInfluence
import statsmodels.api as sm
from sklearn.cluster import DBSCAN,KMeans
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM

# %%
from google.colab import files
downloaded=files.upload()
# Out:
#      <input type="file" id="files-86108b6d-3593-478e-a257-4e063b8e7bcc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86108b6d-3593-478e-a257-4e063b8e7bcc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('spg.csv')
df.head()
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# 2                       1035.4                      0.0                  0.0
# 3                       1035.4                      0.0                  0.0
# 4                       1034.4                      0.0                  0.0
#
#    total_cloud_cover_sfc  high_cloud_cover_high_cld_lay  \
# 0                    0.0                              0
# ...

# %%
df.shape
# Out:
# (4213, 21)

# %%
df.isna().sum()
# Out:
# temperature_2_m_above_gnd            0
# relative_humidity_2_m_above_gnd      0
# mean_sea_level_pressure_MSL          0
# total_precipitation_sfc              0
# snowfall_amount_sfc                  0
# total_cloud_cover_sfc                0
# high_cloud_cover_high_cld_lay        0
# medium_cloud_cover_mid_cld_lay       0
# low_cloud_cover_low_cld_lay          0
# shortwave_radiation_backwards_sfc    0
# wind_speed_10_m_above_gnd            0
# wind_direction_10_m_above_gnd        0
# wind_speed_80_m_above_gnd            0
# wind_direction_80_m_above_gnd        0
# wind_speed_900_mb                    0
# wind_direction_900_mb                0
# wind_gust_10_m_above_gnd             0
# angle_of_incidence                   0
# zenith                               0
# azimuth                              0
# generated_power_kw                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4213 entries, 0 to 4212
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   temperature_2_m_above_gnd          4213 non-null   float64
#  1   relative_humidity_2_m_above_gnd    4213 non-null   int64
#  2   mean_sea_level_pressure_MSL        4213 non-null   float64
#  3   total_precipitation_sfc            4213 non-null   float64
#  4   snowfall_amount_sfc                4213 non-null   float64
#  5   total_cloud_cover_sfc              4213 non-null   float64
#  6   high_cloud_cover_high_cld_lay      4213 non-null   int64
#  7   medium_cloud_cover_mid_cld_lay     4213 non-null   int64
#  8   low_cloud_cover_low_cld_lay        4213 non-null   int64
#  9   shortwave_radiation_backwards_sfc  4213 non-null   float64
#  10  wind_speed_10_m_above_gnd          4213 non-null   float64
# ...

# %%
df.describe()
# Out:
#        temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# count                4213.000000                      4213.000000
# mean                   15.068111                        51.361025
# std                     8.853677                        23.525864
# min                    -5.350000                         7.000000
# 25%                     8.390000                        32.000000
# 50%                    14.750000                        48.000000
# 75%                    21.290000                        70.000000
# max                    34.900000                       100.000000
#
#        mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# count                  4213.000000              4213.000000
# mean                   1019.337812                 0.031759
# std                       7.022867                 0.170212
# min                     997.500000                 0.000000
# 25%                    1014.500000                 0.000000
# ...

# %%
correlation = df.corr()
plt.figure(figsize=(20, 10))
cmap = sns.diverging_palette(220, 20, as_cmap=True)
sns.heatmap(correlation, annot=True, cmap=cmap, fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Looking Data Distribution

# %%
def plot_histogram(data):
  numerical_columns=df.select_dtypes(include=['int64','float64']).columns
  num_of_plots=len(numerical_columns)
  num_of_columns=4
  num_of_rows=(num_of_plots+num_of_columns-1)//num_of_columns
  figs,axes=plt.subplots(num_of_rows,num_of_columns,figsize=(20,num_of_rows*3))
  axes=axes.flatten()
  for i, col in enumerate(numerical_columns):
      ax = axes[i]
      sns.histplot(data[col], ax=ax, kde=True)  # Plot histogram with kernel density estimate
      ax.set_title(f'Histogram of {col}')
      ax.set_xlabel(col)
      ax.set_ylabel('Frequency')

        # Calculate skewness
      skewness = data[col].skew()
      skew_label = 'Positive' if skewness > 0 else 'Negative' if skewness < 0 else 'Symmetric'

        # Add skewness information as text annotation
      ax.text(0.05, 0.9, f'Skewness: {skew_label} ({skewness:.2f})', transform=ax.transAxes, fontsize=10,
                verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

        # Add median line
      median_value = data[col].median()
      ax.axvline(median_value, color='r', linestyle='--', linewidth=1)

    # Adjust layout to prevent overlap of subplots
  plt.tight_layout()

    # Show the plot
  plt.show()

# %%
plot_histogram(df)

# %% [markdown]
# #Shapiro wilk test for checking the normality test

# %%
def shapiro_test(data, alpha=0.05):
    # Perform Shapiro-Wilk test
    stat, p_value = shapiro(data)

    # Print the test result
    print("Shapiro-Wilk Test Result:")
    print("Test Statistic:", stat)
    print("p-value:", p_value)

    # Interpret the test result
    if p_value > alpha:
        print("Conclusion: Fail to reject the null hypothesis (data is normally distributed)")
    else:
        print("Conclusion: Reject the null hypothesis (data is not normally distributed)")

# %%
shapiro_test(df)
# Out:
# Shapiro-Wilk Test Result:
# Test Statistic: 0.49115610122680664
# p-value: 0.0
# Conclusion: Reject the null hypothesis (data is not normally distributed)

# %% [markdown]
# #Kolmogorove test

# %%
def ks_test_normal_for_all_columns(df, alpha=0.05):
    for column in df.columns:
        data = df[column].values.flatten()  # Get values of the current column and flatten to 1D array
        # Perform Kolmogorov-Smirnov test
        stat, p_value = kstest(data, 'norm')

        # Print the test result for the current column
        print(f"Kolmogorov-Smirnov Test Result for column-: {column}:")
        print("Test Statistic:", stat)
        print("p-value:", p_value)

        # Interpret the test result
        if p_value > alpha:
            print("Conclusion: Fail to reject the null hypothesis (data follows a normal distribution)")
        else:
            print("Conclusion: Reject the null hypothesis (data does not follow a normal distribution)")
        print()  # Print an empty line for better readability between columns

# Example usage:
# Assuming df is your DataFrame
ks_test_normal_for_all_columns(df)
# Out:
# Kolmogorov-Smirnov Test Result for column-: temperature_2_m_above_gnd:
# Test Statistic: 0.918784400660457
# p-value: 0.0
# Conclusion: Reject the null hypothesis (data does not follow a normal distribution)
#
# Kolmogorov-Smirnov Test Result for column-: relative_humidity_2_m_above_gnd:
# Test Statistic: 0.9999999999987201
# p-value: 0.0
# Conclusion: Reject the null hypothesis (data does not follow a normal distribution)
#
# Kolmogorov-Smirnov Test Result for column-: mean_sea_level_pressure_MSL:
# Test Statistic: 1.0
# p-value: 0.0
# Conclusion: Reject the null hypothesis (data does not follow a normal distribution)
#
# Kolmogorov-Smirnov Test Result for column-: total_precipitation_sfc:
# Test Statistic: 0.5
# p-value: 0.0
# Conclusion: Reject the null hypothesis (data does not follow a normal distribution)
#
# Kolmogorov-Smirnov Test Result for column-: snowfall_amount_sfc:
# Test Statistic: 0.5
# p-value: 0.0
# ...

# %% [markdown]
# #Checking for multicollinearity

# %%
#Finding out the Pair of features which are highly correlated
def correlated_feature_pair_finder(df,threashold=0.8):
  correlation_matrix=df.corr()
  correlated_pairs=[]
  for i in range (len(correlation_matrix.columns)):
    for j in range(i+1,len(correlation_matrix.columns)):
      if abs(correlation_matrix.iloc[i,j])>threashold:
        pairs=(correlation_matrix.columns[i],correlation_matrix.columns[j])
        correlated_pairs.append(pairs)
  return correlated_pairs

# %%
correlated_feature_pair_finder(df)
# Out:
# [('shortwave_radiation_backwards_sfc', 'zenith'),
#  ('wind_speed_10_m_above_gnd', 'wind_speed_80_m_above_gnd'),
#  ('wind_speed_10_m_above_gnd', 'wind_speed_900_mb'),
#  ('wind_speed_10_m_above_gnd', 'wind_gust_10_m_above_gnd'),
#  ('wind_direction_10_m_above_gnd', 'wind_direction_80_m_above_gnd'),
#  ('wind_direction_10_m_above_gnd', 'wind_direction_900_mb'),
#  ('wind_speed_80_m_above_gnd', 'wind_speed_900_mb'),
#  ('wind_speed_80_m_above_gnd', 'wind_gust_10_m_above_gnd'),
#  ('wind_direction_80_m_above_gnd', 'wind_direction_900_mb'),
#  ('wind_speed_900_mb', 'wind_gust_10_m_above_gnd')]

# %%
correlation = df.corr()
plt.figure(figsize=(20, 10))
cmap = sns.diverging_palette(220, 20, as_cmap=True)
sns.heatmap(correlation, annot=True, cmap=cmap, fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
def calculate_vif(df):
    """
    Calculate the Variance Inflation Factor (VIF) for each independent variable in a DataFrame.

    Parameters:
    df (DataFrame): Input DataFrame containing numerical independent variables.

    Returns:
    DataFrame: DataFrame containing VIF values for each independent variable.
    """
    # Create a DataFrame to store the VIF values
    vif_data = pd.DataFrame()
    vif_data["Variable"] = df.columns
    vif_data["VIF"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]

    return vif_data

# %%
variance=calculate_vif(df)
variance.sort_values(by='VIF',ascending=False)
# Out:
#                              Variable         VIF
# 14                  wind_speed_900_mb  414.860984
# 10          wind_speed_10_m_above_gnd  373.974167
# 2         mean_sea_level_pressure_MSL  183.012461
# 12          wind_speed_80_m_above_gnd   87.181422
# 18                             zenith   70.767714
# 15              wind_direction_900_mb   45.373109
# 11      wind_direction_10_m_above_gnd   35.115426
# 13      wind_direction_80_m_above_gnd   29.079839
# 19                            azimuth   24.642345
# 9   shortwave_radiation_backwards_sfc   23.698273
# 16           wind_gust_10_m_above_gnd   23.304818
# 1     relative_humidity_2_m_above_gnd   23.217398
# 17                 angle_of_incidence   19.320422
# 0           temperature_2_m_above_gnd   16.942094
# 5               total_cloud_cover_sfc   14.527042
# 20                 generated_power_kw    8.284304
# 8         low_cloud_cover_low_cld_lay    6.952723
# 7      medium_cloud_cover_mid_cld_lay    5.373212
# ...

# %%
x=df.drop(['generated_power_kw'],axis=1)
y=df['generated_power_kw']

# %%
mutual_info_regression_results=mutual_info_regression(x,y)

# %%
mutual_info_regression_results
# Out:
# array([0.09536225, 0.12516021, 0.02281286, 0.02290062, 0.00246141,
#        0.08129067, 0.02951106, 0.03906262, 0.06280455, 0.46061951,
#        0.00180313, 0.05023917, 0.02078731, 0.04924511, 0.01588644,
#        0.05070211, 0.        , 0.85553927, 0.60150129, 0.76529035])

# %%
def plot_mutual_info(x, y):
    # Get feature names from DataFrame columns
    feature_names = x.columns.tolist()

    # Calculate mutual information scores
    mi_scores = mutual_info_regression(x, y)

    # Sort features based on mutual information scores
    sorted_indices = np.argsort(mi_scores)
    sorted_feature_names = [feature_names[i] for i in sorted_indices]
    sorted_mi_scores = [mi_scores[i] for i in sorted_indices]

    # Plot the results
    plt.figure(figsize=(10, 6))
    plt.barh(range(len(sorted_feature_names)), sorted_mi_scores, align='center')
    plt.yticks(range(len(sorted_feature_names)), sorted_feature_names)
    plt.xlabel('Mutual Information Gain')
    plt.ylabel('Features')
    plt.title('Mutual Information Gain for Features')
    plt.show()

# %%
plot_mutual_info(x, y)

# %%
x=x.drop(['wind_direction_10_m_above_gnd','wind_direction_900_mb','wind_speed_10_m_above_gnd','wind_speed_900_mb'],axis=1)

# %%
from sklearn.feature_selection import f_regression
def plot_f_test(x, y):
    # Get feature names from DataFrame columns
    feature_names = x.columns.tolist()

    # Calculate F-statistic and p-values
    f_scores, p_values = f_regression(x, y)

    # Sort features based on F-statistic
    sorted_indices = np.argsort(f_scores)
    sorted_feature_names = [feature_names[i] for i in sorted_indices]
    sorted_f_scores = [f_scores[i] for i in sorted_indices]

    # Plot the results
    plt.figure(figsize=(10, 6))
    plt.barh(range(len(sorted_feature_names)), sorted_f_scores, align='center')
    plt.yticks(range(len(sorted_feature_names)), sorted_feature_names)
    plt.xlabel('F-Statistic')
    plt.ylabel('Features')
    plt.title('F-Statistic for Numerical Features')
    plt.show()

# %%
plot_f_test(x, y)

# %% [markdown]
# #Outliers

# %%
def count_outliers_zscore(data, threshold=3):
   # Calculate z-scores for each column using vectorized operations for efficiency
  z_scores = (data - data.mean(axis=0)) / data.std(axis=0)

  # Count outliers based on the specified threshold (consider both positive and negative deviations)
  outlier_counts = ((z_scores.abs() > threshold).sum(axis=0))

  return outlier_counts

# %%
outlier=count_outliers_zscore(x, threshold=3)

# %%
# Plot the results
outlier.plot(kind='bar', figsize=(35, 6), color='skyblue', edgecolor='black')
plt.title('Number of Outliers in Each Column')
plt.xlabel('Columns')
plt.ylabel('Number of Outliers')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
from sklearn.cluster import DBSCAN
def count_outliers_dbscan(data, eps=0.5, min_samples=5):

  # Check for non-numerical columns and raise an error if found
  non_numerics = [col for col in data.columns if not pd.api.types.is_numeric_dtype(data[col])]
  if non_numerics:
    raise ValueError(f"Columns '{', '.join(non_numerics)}' are not numerical. DBSCAN requires numerical data.")

  # Apply DBSCAN to each column separately
  outlier_counts = pd.Series(dtype=int)
  for col in data.columns:
    model = DBSCAN(eps=eps, min_samples=min_samples)
    model.fit(data[[col]])
    outlier_counts.loc[col] = (model.labels_ == -1).sum()  # Count points with label -1 (outliers)

  return outlier_counts

# %%
outlier_db=count_outliers_dbscan(x)

# %%
# Plot the results
outlier_db.plot(kind='bar', figsize=(35, 6), color='skyblue', edgecolor='black')
plt.title('Number of Outliers in Each Column')
plt.xlabel('Columns')
plt.ylabel('Number of Outliers')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
def count_outliers_zscore(data, threshold=3):
   # Calculate z-scores for each column using vectorized operations for efficiency
  z_scores = (data - data.mean(axis=0)) / data.std(axis=0)

  # Count outliers based on the specified threshold (consider both positive and negative deviations)
  outlier_counts = ((z_scores.abs() > threshold).sum(axis=0))

  return outlier_counts

# %%
outlier=count_outliers_zscore(x, threshold=3)

# %%
# Plot the results
outlier.plot(kind='bar', figsize=(35, 6), color='skyblue', edgecolor='black')
plt.title('Number of Outliers in Each Column')
plt.xlabel('Columns')
plt.ylabel('Number of Outliers')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
from sklearn.cluster import DBSCAN
def count_outliers_dbscan(data, eps=0.5, min_samples=5):

  # Check for non-numerical columns and raise an error if found
  non_numerics = [col for col in data.columns if not pd.api.types.is_numeric_dtype(data[col])]
  if non_numerics:
    raise ValueError(f"Columns '{', '.join(non_numerics)}' are not numerical. DBSCAN requires numerical data.")

  # Apply DBSCAN to each column separately
  outlier_counts = pd.Series(dtype=int)
  for col in data.columns:
    model = DBSCAN(eps=eps, min_samples=min_samples)
    model.fit(data[[col]])
    outlier_counts.loc[col] = (model.labels_ == -1).sum()  # Count points with label -1 (outliers)

  return outlier_counts

# %%
outlier_db=count_outliers_dbscan(x)

# %%
# Plot the results
outlier_db.plot(kind='bar', figsize=(35, 6), color='skyblue', edgecolor='black')
plt.title('Number of Outliers in Each Column')
plt.xlabel('Columns')
plt.ylabel('Number of Outliers')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
from sklearn.ensemble import IsolationForest
import pandas as pd

def count_outliers_isolation_forest(data, contamination=0.1):
  # Check for non-numerical columns and raise an error if found
  non_numerics = [col for col in data.columns if not pd.api.types.is_numeric_dtype(data[col])]
  if non_numerics:
    raise ValueError(f"Columns '{', '.join(non_numerics)}' are not numerical. Isolation Forest requires numerical data.")

  # Apply Isolation Forest to each column separately
  outlier_counts = pd.Series(dtype=int)
  for col in data.columns:
    model = IsolationForest(contamination=contamination)
    model.fit(data[[col]])
    outlier_counts.loc[col] = (model.predict(data[[col]]) == -1).sum()  # Count points with label -1 (outliers)

  return outlier_counts

# %%
outlier_iso=count_outliers_isolation_forest(x)

# %%
# Plot the results
outlier_iso.plot(kind='bar', figsize=(35, 6), color='skyblue', edgecolor='black')
plt.title('Number of Outliers in Each Column')
plt.xlabel('Columns')
plt.ylabel('Number of Outliers')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #Spliting and scalling

# %%
x_test,x_train,y_test,y_train=train_test_split(x,y,random_state=42,train_size=20)

# %%
print(x_test.shape)
print(x_train.shape)
print(y_test.shape)
print(y_train.shape)
# Out:
# (20, 16)
# (4193, 16)
# (20,)
# (4193,)

# %%
scaler=StandardScaler()

# %%
x_train_scale=scaler.fit_transform(x_train)

# %%
x_train_scale = pd.DataFrame(x_train_scale, columns=x_train.columns)

# %%
x_test_scale=scaler.fit_transform(x_test)

# %%
x_test_scale = pd.DataFrame(x_test_scale, columns=x_test.columns)

# %% [markdown]
# #Fitting and finding the best Generallized model.

# %%
model_1=LinearRegression()

# %%
model_1.fit(x_train_scale,y_train)
# Out:
# LinearRegression()

# %%
y_pred_model_1=model_1.predict(x_train_scale)

# %%
from sklearn.metrics import r2_score,mean_absolute_percentage_error

# %%
r2_score_model_1=r2_score(y_train,y_pred_model_1)

# %%
mae_model_1=mean_absolute_error(y_train,y_pred_model_1)

# %%
mse_model_1=mean_squared_error(y_train,y_pred_model_1)

# %%
mape_model_1=mean_absolute_percentage_error(y_train,y_pred_model_1)

# %%
n = len(y_train)

# Number of predictors (replace with your actual number of predictors)
k = len(x_train_scale.columns)

# Calculate Adjusted R-squared
adjusted_r2_score_model_1 = 1 - ((1 - r2_score_model_1) * (n - 1)) / (n - k - 1)

print("R-squared-M1:", r2_score_model_1)
print("Adjusted R-squared-M1:", adjusted_r2_score_model_1)
print("Mean Absolute error-M1:", mae_model_1)
print("Mean Squared error-M1:", mse_model_1)
print("Mean Absolute Percentage error-M1:", mape_model_1)
# Out:
# R-squared-M1: 0.7057648862475496
# Adjusted R-squared-M1: 0.7046375486469656
# Mean Absolute error-M1: 391.57718659994754
# Mean Squared error-M1: 258880.18900422245
# Mean Absolute Percentage error-M1: 366.0801672722023

# %% [markdown]
# #Checking on test data

# %%
model_1.fit(x_test_scale,y_test)
# Out:
# LinearRegression()

# %%
y_pred_model_1_test=model_1.predict(x_test_scale)

# %%
r2_score_model_1=r2_score(y_test,y_pred_model_1_test)

# %%
mae_model_1=mean_absolute_error(y_test,y_pred_model_1_test)

# %%
mse_model_1=mean_squared_error(y_test,y_pred_model_1_test)

# %%
mape_model_1=mean_absolute_percentage_error(y_test,y_pred_model_1_test)

# %%
n = len(y_test)

# Number of predictors (replace with your actual number of predictors)
k = len(x_test_scale.columns)

# Calculate Adjusted R-squared
adjusted_r2_score_model_1 = 1 - ((1 - r2_score_model_1) * (n - 1)) / (n - k - 1)

print("R-squared-M1:", r2_score_model_1)
print("Adjusted R-squared-M1:", adjusted_r2_score_model_1)
print("Mean Absolute error-M1:", mae_model_1)
print("Mean Squared error-M1:", mse_model_1)
print("Mean Absolute Percentage error-M1:", mape_model_1)
# Out:
# R-squared-M1: 0.9429437301283138
# Adjusted R-squared-M1: 0.6386436241459872
# Mean Absolute error-M1: 165.07668534765503
# Mean Squared error-M1: 46710.2125876422
# Mean Absolute Percentage error-M1: 0.8607172997390862

# %% [markdown]
# #Model_2

# %%
model_2=DecisionTreeRegressor()

# %%
model_2.fit(x_train_scale,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_model_2=model_2.predict(x_train_scale)

# %%
r2_score_model_2=r2_score(y_train,y_pred_model_2)

# %%
mae_model_2=mean_absolute_error(y_train,y_pred_model_2)

# %%
mse_model_2=mean_squared_error(y_train,y_pred_model_2)

# %%
mape_model_2=mean_absolute_percentage_error(y_train,y_pred_model_2)

# %%
n = len(y_train)

# Number of predictors (replace with your actual number of predictors)
k = len(x_train_scale.columns)

# Calculate Adjusted R-squared
adjusted_r2_score_model_2 = 1 - ((1 - r2_score_model_2) * (n - 1)) / (n - k - 1)

print("R-squared-M2:", r2_score_model_2)
print("Adjusted R-squared-M2:", adjusted_r2_score_model_2)
print("Mean Absolute error-M2:", mae_model_2)
print("Mean Squared error-M2:", mse_model_2)
print("Mean Absolute Percentage error-M2:", mape_model_2)
# Out:
# R-squared-M2: 1.0
# Adjusted R-squared-M2: 1.0
# Mean Absolute error-M2: 0.0
# Mean Squared error-M2: 0.0
# Mean Absolute Percentage error-M2: 0.0

# %% [markdown]
# #Model_2 performance on test data

# %%
model_2.fit(x_test_scale,y_test)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_model_2=model_2.predict(x_test_scale)

# %%
r2_score_model_2=r2_score(y_test,y_pred_model_2)

# %%
mae_model_2=mean_absolute_error(y_test,y_pred_model_2)

# %%
mse_model_2=mean_squared_error(y_test,y_pred_model_2)

# %%
mape_model_2=mean_absolute_percentage_error(y_test,y_pred_model_2)

# %%
n = len(y_test)

# Number of predictors (replace with your actual number of predictors)
k = len(x_test_scale.columns)

# Calculate Adjusted R-squared
adjusted_r2_score_model_2 = 1 - ((1 - r2_score_model_2) * (n - 1)) / (n - k - 1)

print("R-squared-M2:", r2_score_model_2)
print("Adjusted R-squared-M2:", adjusted_r2_score_model_2)
print("Mean Absolute error-M2:", mae_model_2)
print("Mean Squared error-M2:", mse_model_2)
print("Mean Absolute Percentage error-M2:", mape_model_2)
# Out:
# R-squared-M2: 1.0
# Adjusted R-squared-M2: 1.0
# Mean Absolute error-M2: 0.0
# Mean Squared error-M2: 0.0
# Mean Absolute Percentage error-M2: 0.0

# %% [markdown]
# #Model_3 Random forest.

# %%
#Define the parameter grid for GridSearchCV
param_grid = {
    'n_estimators': [100, 200, 300],  # Number of trees in the forest
    'max_depth': [None, 10, 20],  # Maximum depth of the trees
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4]  # Minimum number of samples required to be at a leaf node
}

#Create the Random Forest Regressor
rf_regressor = RandomForestRegressor(random_state=42)

#Create the GridSearchCV object
grid_search = GridSearchCV(estimator=rf_regressor,
                           param_grid=param_grid,
                           scoring='r2',#Using negative MAE as scoring metric
                           cv=5,#5-fold cross-validation

                           )#Use all available CPU cores

#Fit the grid search to the training data
grid_search.fit(x_train_scale, y_train)

#Get the best parameters and the best score
best_params = grid_search.best_params_
best_score = -grid_search.best_score_

print("Best Parameters:",best_params)
print("Best Negative MAE:",best_score)

# %%
n = len(y_test)

# Number of predictors (replace with your actual number of predictors)
k = len(x_test_scale.columns)

# Calculate Adjusted R-squared
adjusted_r2_score_model_2 = 1 - ((1 - r2_score_model_2) * (n - 1)) / (n - k - 1)

print("R-squared-M2:", r2_score_model_2)
print("Adjusted R-squared-M2:", adjusted_r2_score_model_2)
print("Mean Absolute error-M2:", mae_model_2)
print("Mean Squared error-M2:", mse_model_2)
print("Mean Absolute Percentage error-M2:", mape_model_2)
